# %%
import pandas as pd

unpickled_result = pd.read_pickle("./result.pkl")
unpickled_result
# Out:
#                                              Category  \
# 0   Hàng Quốc Tế/Laptop & Máy Vi Tính/Màn hình máy...
# 1   Hàng Quốc Tế/Thiết Bị Số - Phụ Kiện Số/Thiết b...
# 2   Hàng Quốc Tế/Laptop & Máy Vi Tính/Thiết bị lưu...
# 3   Hàng Quốc Tế/Laptop & Máy Vi Tính/Linh kiện má...
# 4   Hàng Quốc Tế/Laptop & Máy Vi Tính/Thiết bị lưu...
# ..                                                ...
# 91  Hàng Quốc Tế/Laptop & Máy Vi Tính/Máy in - Má...
# 92    Hàng Quốc Tế/Laptop & Máy Vi Tính/Thiết bị mạng
# 93  Hàng Quốc Tế/Laptop & Máy Vi Tính/Linh kiện má...
# 94  Hàng Quốc Tế/Laptop & Máy Vi Tính/Thiết bị lưu...
# 95  Hàng Quốc Tế/Laptop & Máy Vi Tính/Máy in - Má...
#
#                                                  Name  Final_price  \
# 0                  Giá Đỡ Màn Hình Brateck LDT12-C011       498000
# 1   USB Thu Wifi Cho Máy Tính Mercury (MERCURY) MW...       179000
# 2                            Túi Đựng Đĩa MNDA CD/DVD       145000
# ...
